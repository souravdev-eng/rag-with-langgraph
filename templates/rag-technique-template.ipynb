# %% [markdown]
# # [Technique Name]
#
# | Field | Value |
# |---|---|
# | Stage | [Foundations / Retrieval / Evaluation / Production] |
# | Difficulty | [Beginner / Intermediate / Advanced] |
# | Status | Draft |
# | Requires network/API | [No / provider and key name] |
# | Last reviewed | YYYY-MM-DD |
#
# Callout - Key idea:
# [One sentence that captures the technique and its main trade-off.]
#
# ## 30-Second Summary
#
# [What problem does it solve, how does it work, and what does it cost?]
#
# ## Why This Matters
#
# [Open with one realistic scenario that continues through the notebook.]
#
# ## Scope
#
# | Covers | Does not cover |
# |---|---|
# | [Learning outcome] | [Intentional boundary] |
#
# ### Prerequisites
#
# [Link the minimum earlier lessons and list required credentials or downloads.]

# %% [markdown]
# ## Mental Model
#
# [Place one overview diagram directly here. Show relationships and flow; do not merely restate prose.]
#
# ```text
# input -> baseline -> technique -> measurable result
# ```
#
# [Explain the mechanism and boundary in one to three short paragraphs.]

# %% [markdown]
# ### Setup and Configuration
#
# Keep model names and important parameters in this section. The default path should be local when practical.

# %%
from pathlib import Path


def find_repo_root(start: Path | None = None) -> Path:
    current = (start or Path.cwd()).resolve()
    for candidate in (current, *current.parents):
        if (candidate / "pyproject.toml").is_file():
            return candidate
    raise FileNotFoundError("Run this notebook from inside the repository.")


REPO_ROOT = find_repo_root()
SEED = 42
REPO_ROOT

# %% [markdown]
# ## How It Works
#
# [Explain the steps or algorithm. Define each important parameter and invariant.]

# %% [markdown]
# ## Baseline
#
# [Build the simplest valid alternative first. State the expected weakness.]

# %%
# Replace with the smallest runnable baseline.
baseline_result = {"retrieved_ids": [], "answer": None}
baseline_result

# %% [markdown]
# ## Technique Implementation
#
# [Implement enough mechanics from scratch to expose the idea, then show the framework version if useful.]

# %%
# Replace with the technique under study.
technique_result = {"retrieved_ids": [], "answer": None}
technique_result

# %% [markdown]
# ## Controlled Experiment
#
# [Use the same data, questions, and evaluation method for baseline and technique. Change one primary variable.]

# %%
# Record concise, inspectable results rather than dumping full documents.
experiment_results = []
experiment_results

# %% [markdown]
# ## Evaluation
#
# | Signal | Why it matters | Baseline | Technique |
# |---|---|---:|---:|
# | [Retrieval metric] | [Interpretation] | [value] | [value] |
# | [Answer metric] | [Interpretation] | [value] | [value] |
# | Latency | Operational cost | [value] | [value] |
#
# [State what the measurements prove and what they do not prove.]

# %%
# Add at least one behavioral assertion for the real lesson.
assert isinstance(experiment_results, list)

# %% [markdown]
# ## Decision Guide
#
# | Situation | Choose | Reason | Trade-off |
# |---|---|---|---|
# | [Condition] | [Option] | [Why] | [Cost/risk] |
#
# [Include a clear 'do not use this when...' boundary.]

# %% [markdown]
# ## Failure Modes and Debugging
#
# | Symptom | Likely cause | How to verify | Fix |
# |---|---|---|---|
# | [Observed failure] | [Root cause] | [Diagnostic] | [Correction] |

# %% [markdown]
# ## Production Notes
#
# ### Observability
# [What should be traced, logged, and monitored?]
#
# ### Safety and Guardrails
# [What data, authorization, injection, or output risks apply?]
#
# ### Latency and Cost
# [What work happens per document and per query? Where are the budgets?]

# %% [markdown]
# ## Practice
#
# [One exercise that changes a meaningful variable and predicts the result before execution.]

# %% [markdown]
# ## Recall
#
# Toggle - Recall: What problem does this technique solve?
# [Answer in one or two sentences.]
#
# Toggle - Recall: When should you not use it?
# [Answer.]
#
# Toggle - Recall: Which metric should move if it works?
# [Answer.]
#
# Toggle - Recall: What is the most common production failure?
# [Answer.]

# %% [markdown]
# ## Sources
#
# - [Official documentation or original paper]
# - [Repository/course source, if applicable]
#
# Clearly separate sourced behavior from notebook interpretation.

# %% [markdown]
# ## Review Log
#
# | Date | Status | Confidence | Next review focus |
# |---|---|---|---|
# | YYYY-MM-DD | Draft | Low / Medium / High | [Weak point] |
